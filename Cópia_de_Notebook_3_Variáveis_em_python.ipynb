# %% [markdown]
# <a href="https://colab.research.google.com/github/BrunoLeandro1986/Projeto_pytho/blob/main/C%C3%B3pia_de_Notebook_3_Vari%C3%A1veis_em_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Aula 03 - 14 Maio/2026
#
# # UC: Programação em Python - 80h
#
# # **Variáveis, Operações, Condições**
#
# Logística: Google Colaboratory
#
# * Pressione Shift + Enter para executar cada bloco de código no ambiente do Google Colab ou copie e cole os códigos/comentários em um arquivo python.
# * As apresentações e explicações conceituais são fornecidas em blocos de texto. As explicações relacionadas aos códigos são incluídas como comentários acima dos códigos.
# * Exercícios/problemas práticos são indicados em cada módulo. Para exercícios de codificação, você pode baixar uma IDE externa de Python (por exemplo, Anaconda) para programar e testar sua implementação. Uma possível implementação do exercício é fornecida sob o problema.
#
# Objetivos de aprendizado:
#
# 1. Definir e modificar variáveis de vários tipos de dados. Converter entre tipos de dados.
# 2. Compreender as características e usos de cada operação e a saída (output) correspondente.
# 3. Compreender e corrigir estas declarações para verificar as condições.
#
# 1.1 Variáveis
#
# 1.1.1 Atribuição de Variáveis
# As variáveis são as mesmas que as variáveis em matemática, exceto que variáveis matemáticas são muitas vezes letras, mas variáveis de programação podem ser palavras.
#
# Variáveis: um conjunto que contém algumas informações.
#
# Nota sobre a declaração de variáveis:
#
# * Case-sensitive (ou seja, caracteres em caixa alta ou baixa são tratados como diferentes)
# * DEVE começar com uma letra ou um sublinhado; NÃO PODE começar com números.
# * NÃO PODE ser o mesmo nome que as palavras-chave Python (por exemplo, class, finally, etc.)
# * NÃO especificar o tipo de informação armazenada na variável. (Consulte os seguintes códigos para um exemplo.)

# %%
# Exemplo 2.1 de declarações de variáveis
width = 10

# Note que o "H" está em letra maiúscula
Height = 5

# Exemplo de variável
area = 0

# A função print() em Python exibe informações no terminal, convertendo objetos em texto.
print(width)
print(Height)
print(area)

# %%
width
# Out:
# 10

# %%
Height
# Out:
# 5

# %%
area
# Out:
# 0

# %%
# Exemplo 2.2

import builtins

# Usando uma palavra-chave python como um nome variável
# ERROR CODE: sintaxe inválida

# global = 1 # Isso gera um SyntaxError

# Vamos usar um nome de variável diferente para evitar o conflito com a palavra-chave 'global'
my_global_var = 1

# Para demonstrar que 'global' é uma palavra-chave, podemos verificar se está nas palavras-chave reservadas.
# No entanto, 'global' é um statement, não uma função ou tipo de dado que você possa simplesmente imprimir.
# Para listar palavras-chave, você precisaria do módulo keyword.
# Mas para este exemplo, basta saber que não pode ser usado como nome de variável.
print(my_global_var)
# Out:
# 1

# %%
# Exemplo 2.3

# Mais declarações para diferentes tipos de variáveis

# armazenando uma string
helloMessage = 'Olá, Mundo!'
first_name = 'John'

# armazenando um caractere
character_examplo = 'a'

# armazenando um float
_newFloat = 1.0

# armazenando um valor booleano
bool_Condition = True

# %%
# Exemplo 2.4

# Exemplo de especificadores de formato (f-strings)
preco = 19.99
quantidade = 3
total = preco * quantidade

# :.2f - Formata float com 2 casas decimais
# :03d - Formata inteiro com 3 dígitos, preenchendo com zeros à esquerda
print(f'Total: R$ {total:.2f} (Qtd: {quantidade:03d})')
# Saída: Total: R$ 59.97 (Qtd: 003)
# Out:
# Total: R$ 59.97 (Qtd: 003)

# %%
# Exercício 2.5

largura = float
comprimento = float
valor = float
area = float
preco = float

largura = float(input('Digite a largura do terreno: '))
comprimento = float(input('Digite o comprimento do terreno: '))
valor = float(input('Digite o valor do metro quadrado: '))

area = largura * comprimento

print(f"Area do terreno = {area:.2f}")

preco = area * valor

print(f"Preco do terreno = {preco:.2f}\n")

largura = float
comprimento = float
valor = float
area = float
preco = float

largura = float(input('Digite a largura do terreno: '))
comprimento = float(input('Digite o comprimento do terreno: '))
valor = float(input('Digite o valor do metro quadrado: '))

area = largura * comprimento

print(f"Area do terreno = {area:.2f}")

preco = area * valor

print(f"Preco do terreno = {preco:.2f}\n")
# Out:
# Digite a largura do terreno: 80
# Digite o comprimento do terreno: 70
# Digite o valor do metro quadrado: 60
# Area do terreno = 5600.00
# Preco do terreno = 336000.00
#
# Digite a largura do terreno: 60
# Digite o comprimento do terreno: 60
# Digite o valor do metro quadrado: 80
# Area do terreno = 3600.00
# Preco do terreno = 288000.00

# %% [markdown]
# 1.1.2 Conversor de Tipo
#
# A partir do tópico
#
# 1.1.1 Aprendemos como declarar corretamente um nome variável para diferentes tipos de dados. Neste tópico, vamos explorar como computar ou converter otipo dos dados entre si.
#
# Uma função útil: type() define o tipo dos dados.

# %%
# Exemplo 2.7

# A partir da declaração acima, width = 10 e 10 é int,
# então esperamos que a função retorne int

type(10)
# Out:
# int

# %%
type(helloMessage)
# Out:
# str

# %%
type(bool_Condition)
# Out:
# bool

# %%
# Exemplo 2.7

# Vamos computar um float em um int e vice-versa
# Computaremos o tipo e depois o armazenaremos em uma nova variável
width_float = float

type(width_float)
# Out:
# type

# %%
# Exercício 2.8
# Computar de float para int
width_int = int(width_float)

type(width_int)
# Out:
# int

# %%
# Exercício 2.9
# Computar entre string e int
# Lembrar que width armazena um int

# Converter width para string
width_string = str(width)
type(width_string)
# Out:
# str

# %%
# Exercício 2.10
# Computar entre string e int
# Lembrar que width armazena um int

# Converter width para string
width_string = str(width)
type(width_string)
# Out:
# str

# %% [markdown]
# 1.2: Operações
#
# 1.1.1 Operadores Aritméticos

# %%
# Exercício 2.11
# Operações matemáticas básicas com Números

# Adição
print(5 + 23)

# Subtração
print(100 - 25)

# Multiplicação
print(5 * 10)

# Potência/Exponente
# o operador ** é equivalente ao expoente
print(5 ** 2)

# 5 * 5 = 5 ^ 2 = 5 ** 2
print(5 * 5)


# Divisão (float)
# Retornar o valor decimal real da divisão
print(36 / 4)
print(10 / 3)

# Divisão (int)
# Retornar um int. Se o quociente real for um valor decimal, apenas um número inteiro irá retornar
print(10 // 3)
print(19 // 6)

# Divisão Modular: retornar o restante da divisão
print(10 % 3)
# Out:
# 28
# 75
# 50
# 25
# 25
# 9.0
# 3.3333333333333335
# 3
# 3
# 1

# %%
# Exercício 2.12
# Operações com Strings e Caracteres
print("foo" * 5)
print('x' * 3)
# Out:
# foofoofoofoofoo
# xxx

# %%
# Exercício 2.13
# ERRO: o compilador trata x como uma variável, não como um caractere
print(x * 3)
# Out:
# 21

# %%
# Exercício 2.14
# ERRO: não pode concatenar um int com uma string --> necessidade de computar int com uma string
print("hello" + 5)

# %%
# Exercício 2.15
# Fix
print("hello " + str(5))
# Out:
# hello 5

# %%
# Exercício 2.16
# Adição de String = concatenação
print("hello " + "world")
# Out:
# hello world

# %% [markdown]
# 1.1.2: Outros Operadores

# %%
# Exercício 2.17
# Comparadores: retornar valor booleano

# Igualdade ==
# Nota: DEVE ser sinais de igual Duplos, um sinal de igual único é atribuição
print(5 == 5.0)

# Maior do que >
print(7 > 1)

# Menor do que <
print(1.5 < 90)

# Maior ou igual a >=
print(5.0 >= 5)
print(5.0 >= 4)
print(5 >= 13)

# Menor ou igual a <=
print(10 <= 10.0)
print(10 <= 20)
print(8 <= 3)
# Out:
# True
# True
# True
# True
# True
# False
# True
# True
# False

# %%
# Exercício 2.18
# Comparadores em Strings

print("oi" < "mundo")
print("oi" == "mundo")
print("oi" > "mundo")
print("oi" == "oi")
print("gato" < "cachorro")
# Out:
# False
# False
# True
# True
# False

# %% [markdown]
# 1.3: Declarações Condicionais
#
# 1.3.1: Estrutura Condicional If

# %% [markdown]
# Avisos importantes:
#
# * A ordem das condições importa!
#   - Se mais de uma condição estiver satisfeita, então as ações associadas à primeira condição satisfeita serão executadas e saltarão as demais condições e códigos.
# * "elif" = "else if"
#   - "elif" expressa o mesmo significado que "else if"
# * Pelo menos uma condição DEVE ser prevista para ambas as cláusulas if e elif, senão ERROR!
# * Os parênteses para if e elif são opcionais. Seu código funcionará com ou sem o ().

# %%
# Exercício 2.19
x = 7
y = 14


if (2 * x == y):
  print("y é o dobro de x")
elif (x ** 2 == y):
  print("y é o quadrado de x")
else:
  print("y não é o dobro de x")
# Out:
# y é o dobro de x

# %%
# Exercício 2.20
x = 7
y = 49


if (2 * x == y):
  print("y é o dobro de x")
elif (x ** 2 == y):
  print("y é o quadrado de x")
else:
  print("y não é o dobro de x")
# Out:
# y é o quadrado de x

# %%
# Exercício 2.21
x = 7
y = 50


if (2 * x == y):
  print("y é o dobro de x")
elif (x ** 2 == y):
  print("y é o quadrado de x")
else:
  print("y não é o dobro nem o quadrado de x")
# Out:
# y não é o dobro nem o quadrado de x

# %% [markdown]
# Condicional Simples (if)
# A estrutura mais básica. Só executa uma ação se a condição for verdadeira. Se for falsa, o programa simplesmente segue adiante sem fazer nada.

# %%
# Exercício 2.22
idade = int(input("Qual é a sua idade? "))

if idade >= 18:
    print("Você já pode tirar a carteira de motorista!")

print("Fim do programa.")
# Out:
# Qual é a sua idade? 18
# Você já pode tirar a carteira de motorista!
# Fim do programa.

# %% [markdown]
# 1.3.2: Switch Cases
#
# O Python NÃO tem uma implementação para os switch cases, mas uma maneira de implementá-lo é com o dicionário, uma estrutura de dados que armazena o par de valores chave (Módulo 3).
#
# * As condições switch são armazenadas como chaves no dicionário, e as ações armazenadas como valor.
#   - Se houver uma série de ações para cada caso, então considere escrever uma função para cada caso e use as chamadas de função como o valor.
# * A condição padrão é listada manualmente como um valor chave no get().

# %%
# Exercício 2.23
def switcher(numero):

  # Use dicionário para armazenar switch cases
  # Se não for encontrado, o get() será o valor padrão
  return {
    '0':"Entrou 0",
    '1':"Entrou 1",
    '2':"Entrou 2",
    '3':"Entrou 3",
    '4':"Entrou 4",
    '5':"Entrou 5",
    '6':"Entrou 6",
    '7':"Entrou 7",
    '8':"Entrou 8",
    '9':"Entrou 9",
  }.get(numero,"Número inválido!")


# input() lê uma entrado do usuário de stdin
numero = input("Digite um número: ")
switcher(numero)
# Out:
# Digite um número: 20
# 'Número inválido!'

# %%
"""
EXERCÍCIO: implemente o exemplo de switch case acima usando as condições "if/else"

Prompt: para cada dígito entre 0-9, o programa imprimirá uma confirmação
para o valor inserido ou irá imprimir "invalid inputs" para todos os outros números.
"""

# %%
numero = input("Digite um número: ")

if numero == '0':
    print("Entrou 0")
elif numero == '1':
    print("Entrou 1")
elif numero == '2':
    print("Entrou 2")
elif numero == '3':
    print("Entrou 3")
elif number == '4':
    print("Entrou 4")
elif number == '5':
    print("Entrou 5")
elif number == '6':
    print("Entrou 6")
elif number == '7':
    print("Entrou 7")
elif number == '8':
    print("Entrou 8")
elif number == '9':
    print("Entrou 9")
else:
    print("Número inválido!")
# Out:
# Digite um número: 2
# Entrou 2
